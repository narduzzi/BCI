# %% [markdown]
# # Bihavior Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bokeh as bk
import os

# %%
list_recordings = os.listdir("Recordings/")
list_recordings
# Out:
# ['ad3_08032017', 'ad6_10032017', 'ah2_31032017']

# %%
def createDFfor(folder):
    path = "Recordings/"+folder+"/"
    comparison = pd.read_csv(str(path)+str(folder)+"_comparison.csv")
    questionaire = pd.read_csv(str(path)+str(folder)+"_questionaire.csv")
    #Add folder for tracing
    questionaire["Folder"] = folder
    comparison["Folder"] = folder
    
    return comparison,questionaire

# %%
def cleanColumns(columns):
    rep_col = []
    for c in columns:
        c = c.replace("\n"," ")
        rep_col.append(c)
    return rep_col

# %%
comparisonDF = pd.DataFrame()
questionaireDF = pd.DataFrame()

for folder in list_recordings:
    comparison,questionaire = createDFfor(folder)
    comparison.columns = cleanColumns(comparison.columns)
    questionaire.columns = cleanColumns(questionaire.columns)
        
    comparisonDF = comparisonDF.append(comparison)
    questionaireDF = questionaireDF.append(questionaire)

# %%
questionaireDF
# Out:
#              (0-20)         (0-20).1     (0-20).2 (0-20).3     (0-20).4  \
# 0               NaN              NaN          NaN      NaN          NaN
# 1               NaN              NaN          NaN      NaN          NaN
# 2               NaN              NaN          NaN      NaN          NaN
# 3               NaN              NaN          NaN      NaN          NaN
# 4               NaN              NaN          NaN      NaN          NaN
# 5               NaN              NaN          NaN      NaN          NaN
# 6               NaN              NaN          NaN      NaN          NaN
# 7               NaN              NaN          NaN      NaN          NaN
# 8               NaN              NaN          NaN      NaN          NaN
# 9               NaN              NaN          NaN      NaN          NaN
# 10              NaN              NaN          NaN      NaN          NaN
# 11              NaN              NaN          NaN      NaN          NaN
# 12              NaN              NaN          NaN      NaN          NaN
# 13              NaN              NaN          NaN      NaN          NaN
# 14              NaN              NaN          NaN      NaN          NaN
# 15              NaN              NaN          NaN      NaN          NaN
# 0               NaN              NaN          NaN      NaN          NaN
# 1               NaN              NaN          NaN      NaN          NaN
# 2               NaN              NaN          NaN      NaN          NaN
# 3               NaN              NaN          NaN      NaN          NaN
# 4               NaN              NaN          NaN      NaN          NaN
# 5               NaN              NaN          NaN      NaN          NaN
# 6               NaN              NaN          NaN      NaN          NaN
# 7               NaN              NaN          NaN      NaN          NaN
# 8               NaN              NaN          NaN      NaN          NaN
# 9               NaN              NaN          NaN      NaN          NaN
# 10              NaN              NaN          NaN      NaN          NaN
# 11              NaN              NaN          NaN      NaN          NaN
# 12              NaN              NaN          NaN      NaN          NaN
# 13              NaN              NaN          NaN      NaN          NaN
# 14              NaN              NaN          NaN      NaN          NaN
# 15              NaN              NaN          NaN      NaN          NaN
# 0   Physical Demand  Temporal Demand  Performance   Effort  Frustration
# 1                 3               10           13        8            8
# 2                 2                5            2        3            7
# 3                 2                5            0        3            3
# 4                 5               12            7        6            5
# 5                 4               10           10        7            4
# 6                 4               13           16        9            7
# 7                 2                6            0        6            4
# 8                 4               10           11        8            9
# 9                 3                9            8        8            6
# 10                3                8            7        9            6
# 11                4                7           15        8            9
# 12                3                9           17        9           10
# 13                4                9            7       19            5
# 14                2                9            4       14            6
# 15                2                8            0        9            3
#
#              (1-20)         (1-20).1     (1-20).2 (1-20).3     (1-20).4  \
# 0   Physical Demand  Temporal Demand  Performance   Effort  Frustration
# 1                 2                2           15        5            2
# 2                 1                1           17        4            1
# 3                 1                1           17        3            1
# 4                15               17            5       15           10
# 5                16               18            4       15           12
# 6                17               18            3       16           14
# 7                18               19            3       17           15
# 8                17               18            3       16           15
# 9                 1                1           16        2            1
# 10                1                1           17        2            1
# 11               14               16            5       14           13
# 12               15               17            5       15           14
# 13               13               15            7       12           10
# 14               16               17            3       14           15
# 15               17               17            8       15            9
# 0   Physical Demand  Temporal Demand  Performance   Effort  Frustration
# 1                 2                8           15        4            2
# 2                 6                8           17        4            1
# 3                10               10            4       10            9
# 4                11               14            7       12            8
# 5                11               14           10       12            8
# 6                11               14           10       12            6
# 7                 4                2           18        7            1
# 8                10               13           10       13            9
# 9                10               16           10       13            9
# 10                7               11           11       10            8
# 11               10                9           15       13            4
# 12                3                4           18        5            0
# 13                6               10           14        9            3
# 14                7               12           14       10            4
# 15                2                2           20        1            0
# 0               NaN              NaN          NaN      NaN          NaN
# 1               NaN              NaN          NaN      NaN          NaN
# 2               NaN              NaN          NaN      NaN          NaN
# 3               NaN              NaN          NaN      NaN          NaN
# 4               NaN              NaN          NaN      NaN          NaN
# 5               NaN              NaN          NaN      NaN          NaN
# 6               NaN              NaN          NaN      NaN          NaN
# 7               NaN              NaN          NaN      NaN          NaN
# 8               NaN              NaN          NaN      NaN          NaN
# 9               NaN              NaN          NaN      NaN          NaN
# 10              NaN              NaN          NaN      NaN          NaN
# 11              NaN              NaN          NaN      NaN          NaN
# 12              NaN              NaN          NaN      NaN          NaN
# 13              NaN              NaN          NaN      NaN          NaN
# 14              NaN              NaN          NaN      NaN          NaN
# 15              NaN              NaN          NaN      NaN          NaN
#
#    0-100 0: like normal breathing 100: impossible        Folder  \
# 0                                      Difficulty  ad3_08032017
# 1                                              10  ad3_08032017
# 2                                               6  ad3_08032017
# 3                                               5  ad3_08032017
# 4                                              80  ad3_08032017
# 5                                              82  ad3_08032017
# 6                                              88  ad3_08032017
# 7                                              89  ad3_08032017
# 8                                              88  ad3_08032017
# 9                                               4  ad3_08032017
# 10                                              3  ad3_08032017
# 11                                             75  ad3_08032017
# 12                                             80  ad3_08032017
# 13                                             70  ad3_08032017
# 14                                             85  ad3_08032017
# 15                                             65  ad3_08032017
# 0                                      Difficulty  ad6_10032017
# 1                                               5  ad6_10032017
# 2                                               4  ad6_10032017
# 3                                              70  ad6_10032017
# 4                                              70  ad6_10032017
# 5                                              70  ad6_10032017
# 6                                              60  ad6_10032017
# 7                                               5  ad6_10032017
# 8                                              60  ad6_10032017
# 9                                              60  ad6_10032017
# 10                                             60  ad6_10032017
# 11                                             58  ad6_10032017
# 12                                              5  ad6_10032017
# 13                                             40  ad6_10032017
# 14                                             55  ad6_10032017
# 15                                              2  ad6_10032017
# 0                                      Difficulty  ah2_31032017
# 1                                              80  ah2_31032017
# 2                                              10  ah2_31032017
# 3                                              10  ah2_31032017
# 4                                              70  ah2_31032017
# 5                                              70  ah2_31032017
# 6                                              90  ah2_31032017
# 7                                              10  ah2_31032017
# 8                                              70  ah2_31032017
# 9                                              70  ah2_31032017
# 10                                             60  ah2_31032017
# 11                                             80  ah2_31032017
# 12                                             80  ah2_31032017
# 13                                             80  ah2_31032017
# 14                                             20  ah2_31032017
# 15                                             20  ah2_31032017
#
#    NASA-TLX (0-20) 0: very low 20: very high  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 0                              Mental Demand
# 1                                         16
# 2                                          7
# 3                                          6
# 4                                         16
# 5                                         16
# 6                                         16
# 7                                          8
# 8                                         14
# 9                                         15
# 10                                        13
# 11                                        15
# 12                                        14
# 13                                        13
# 14                                        15
# 15                                        10
#
#    NASA-TLX (1-20) 1: very low 20: very high  Unnamed: 0
# 0                              Mental Demand  trajectory
# 1                                          4           1
# 2                                          3           2
# 3                                          2           3
# 4                                         15           4
# 5                                         16           5
# 6                                         17           6
# 7                                         17           7
# 8                                         16           8
# 9                                          2           9
# 10                                         1          10
# 11                                        15          11
# 12                                        16          12
# 13                                        14          13
# 14                                        16          14
# 15                                        16          15
# 0                              Mental Demand  trajectory
# 1                                          3           1
# 2                                          2           2
# 3                                         10           3
# 4                                         10           4
# 5                                         11           5
# 6                                         12           6
# 7                                          5           7
# 8                                         14           8
# 9                                         14           9
# 10                                        11          10
# 11                                         8          11
# 12                                         2          12
# 13                                        10          13
# 14                                        12          14
# 15                                         1          15
# 0                                        NaN  trajectory
# 1                                        NaN           1
# 2                                        NaN           2
# 3                                        NaN           3
# 4                                        NaN           4
# 5                                        NaN           5
# 6                                        NaN           6
# 7                                        NaN           7
# 8                                        NaN           8
# 9                                        NaN           9
# 10                                       NaN          10
# 11                                       NaN          11
# 12                                       NaN          12
# 13                                       NaN          13
# 14                                       NaN          14
# 15                                       NaN          15
